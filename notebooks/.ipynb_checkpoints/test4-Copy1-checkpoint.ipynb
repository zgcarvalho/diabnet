# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve,f1_score, accuracy_score, balanced_accuracy_score, brier_score_loss
sys.path.append("../")
from diabnet.apply import Predictor

# %%
def get_feature_names(fn, BMI=False):
    import pandas as pd 
    import numpy as np
    col_names = pd.read_csv(fn).columns.values
    # features = np.delete(col_names, ['id','BMI','T2D'])
    if BMI:
        features = np.setdiff1d(col_names, np.array(['id','T2D']), assume_unique=True)
    else:
        features = np.setdiff1d(col_names, np.array(['id','BMI','T2D']), assume_unique=True)
    return list(features)

# %%
c = get_feature_names("../datasets/visits_checked_unique_test_positivo_1000_random_0.csv", BMI=False)

# %%
pred = Predictor('../diabnet/models/teste-checked.pth', c, 'data/negatives_older60_from_positivo_1000_random_0.csv')

# %% [markdown]
# # Testes para o modelo

# %% [markdown]
# ## Testes utilizando todo o conjunto de teste
#
# Os resultados abaixo utilizam todos os 488 indivíduos do conjunto de teste.
#
# No conjunto há 128 positivos para diabetes.

# %%
# o conjunto de testes possui ids repetidos devido as visitas (idades diferentes) 
# abaixo é feita a leitura dos dados retirando a repetição de ids, mantendo a maior idade e estado diabetico caso tenha sido observado em alguma visita  
df = pd.read_csv("../datasets/visits_sp_unique_test_positivo_1000_random_0.csv").groupby('id').max()
features = df[c].values
labels = df['T2D'].values

# %%
df
# Out:
#         snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# id
# A00124                0               0               0               0
# A00137                0               0               0               0
# A00144                0               0               0               0
# A00145                0               0               0               0
# A00148                0               0               0               0
# ...                 ...             ...             ...             ...
# A46038                0               0               0               0
# A46041                0               0               0               0
# A46047                0               1               0               1
# A46054                0               2               0               0
# A46057                0               1               0               1
#
#         snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# id
# ...

# %%
# as predições são feitas em diferentes idades para avaliar como isso influencia no resultado
# por default da funcao pred.patient cada predicao é realizada 100 vezes. O valor final do individuo é a mediana dessas prediçoes
predictions = [[np.median(pred.patient(f, age=age)) for f in features] for age in range(20,80,5)]

# %%
aucs = [roc_auc_score(labels,pr) for pr in predictions]
for i in zip(range(20,80,5), aucs):
    print("Predictions using patient age = {} have AUC = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have AUC = 0.8646
# Predictions using patient age = 25 have AUC = 0.8695
# Predictions using patient age = 30 have AUC = 0.8709
# Predictions using patient age = 35 have AUC = 0.8734
# Predictions using patient age = 40 have AUC = 0.8737
# Predictions using patient age = 45 have AUC = 0.8723
# Predictions using patient age = 50 have AUC = 0.8736
# Predictions using patient age = 55 have AUC = 0.8714
# Predictions using patient age = 60 have AUC = 0.8696
# Predictions using patient age = 65 have AUC = 0.8684
# Predictions using patient age = 70 have AUC = 0.8667
# Predictions using patient age = 75 have AUC = 0.8652

# %%
f1s = [f1_score(labels,np.round(pr)) for pr in predictions]
for i in zip(range(20,80,5), f1s):
    print("Predictions using patient age = {} have F1-Score = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have F1-Score = 0.4766
# Predictions using patient age = 25 have F1-Score = 0.5315
# Predictions using patient age = 30 have F1-Score = 0.5603
# Predictions using patient age = 35 have F1-Score = 0.6041
# Predictions using patient age = 40 have F1-Score = 0.6667
# Predictions using patient age = 45 have F1-Score = 0.6643
# Predictions using patient age = 50 have F1-Score = 0.6804
# Predictions using patient age = 55 have F1-Score = 0.6951
# Predictions using patient age = 60 have F1-Score = 0.7022
# Predictions using patient age = 65 have F1-Score = 0.6936
# Predictions using patient age = 70 have F1-Score = 0.6721
# Predictions using patient age = 75 have F1-Score = 0.6527

# %%
accs = [accuracy_score(labels,np.round(pr)) for pr in predictions]
for i in zip(range(20,80,5), accs):
    print("Predictions using patient age = {} have Accuracy = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have Accuracy = 0.7964
# Predictions using patient age = 25 have Accuracy = 0.8109
# Predictions using patient age = 30 have Accuracy = 0.8145
# Predictions using patient age = 35 have Accuracy = 0.8236
# Predictions using patient age = 40 have Accuracy = 0.8418
# Predictions using patient age = 45 have Accuracy = 0.8309
# Predictions using patient age = 50 have Accuracy = 0.8309
# Predictions using patient age = 55 have Accuracy = 0.8309
# Predictions using patient age = 60 have Accuracy = 0.8273
# Predictions using patient age = 65 have Accuracy = 0.8073
# Predictions using patient age = 70 have Accuracy = 0.7818
# Predictions using patient age = 75 have Accuracy = 0.7582

# %%
baccs = [balanced_accuracy_score(labels,np.round(pr)) for pr in predictions]
for i in zip(range(20,80,5), baccs):
    print("Predictions using patient age = {} have Balanced Accuracy = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.6546
# Predictions using patient age = 25 have Balanced Accuracy = 0.6802
# Predictions using patient age = 30 have Balanced Accuracy = 0.6944
# Predictions using patient age = 35 have Balanced Accuracy = 0.7181
# Predictions using patient age = 40 have Balanced Accuracy = 0.7560
# Predictions using patient age = 45 have Balanced Accuracy = 0.7581
# Predictions using patient age = 50 have Balanced Accuracy = 0.7716
# Predictions using patient age = 55 have Balanced Accuracy = 0.7852
# Predictions using patient age = 60 have Balanced Accuracy = 0.7943
# Predictions using patient age = 65 have Balanced Accuracy = 0.7958
# Predictions using patient age = 70 have Balanced Accuracy = 0.7838
# Predictions using patient age = 75 have Balanced Accuracy = 0.7712

# %%
for pr in predictions:
    fpr, tpr, threshold = roc_curve(labels,pr)
    plt.plot(fpr, tpr)
plt.ylim(0,1);
plt.xlim(0,1);
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.savefig('test-auc-all-testset.png')

# %%
for pr in predictions:
    precision, recall, _ = precision_recall_curve(labels, pr)
    plt.step(recall, precision,where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.savefig('test-precision-recall-all-testset.png')

# %%
precision, recall, threshold = precision_recall_curve(labels, predictions[7])
print(precision[362], recall[362], threshold[362])
# Out:
# 0.7094594594594594 0.6730769230769231 0.50828224

# %% [markdown]
# ## Conjunto de testes reduzido
#
# Aparentemente há uma influência de indivíduos jovens negativos, os quais podem ter um genótipo favorável à ocorrência de diabetes, mas poderiam não terem desenvolvido ainda devido a pouca idade.

# %%
# total 242 individuos dos quais 128 são positivos e 114 são negativos com mais de 50 anos   
df_age50 = df[(df.T2D > 0.5) | (df.AGE >= 50)]
features_age50 = df_age50[c].values
labels_age50 = df_age50['T2D'].values

# %%
predictions_age50 = [[np.median(pred.patient(f, age=age)) for f in features_age50] for age in range(20,80,5)]

# %%
aucs_age50 = [roc_auc_score(labels_age50,pr) for pr in predictions_age50]
for i in zip(range(20,80,5), aucs_age50):
    print("Predictions using patient age = {} have AUC = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have AUC = 0.8861
# Predictions using patient age = 25 have AUC = 0.8885
# Predictions using patient age = 30 have AUC = 0.8924
# Predictions using patient age = 35 have AUC = 0.8929
# Predictions using patient age = 40 have AUC = 0.8949
# Predictions using patient age = 45 have AUC = 0.8924
# Predictions using patient age = 50 have AUC = 0.8909
# Predictions using patient age = 55 have AUC = 0.8902
# Predictions using patient age = 60 have AUC = 0.8882
# Predictions using patient age = 65 have AUC = 0.8887
# Predictions using patient age = 70 have AUC = 0.8854
# Predictions using patient age = 75 have AUC = 0.8830

# %%
f1s_age50 = [f1_score(labels_age50,np.round(pr)) for pr in predictions_age50]
for i in zip(range(20,80,5), f1s_age50):
    print("Predictions using patient age = {} have F1-Score = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have F1-Score = 0.4952
# Predictions using patient age = 25 have F1-Score = 0.5413
# Predictions using patient age = 30 have F1-Score = 0.5867
# Predictions using patient age = 35 have F1-Score = 0.6468
# Predictions using patient age = 40 have F1-Score = 0.7020
# Predictions using patient age = 45 have F1-Score = 0.7120
# Predictions using patient age = 50 have F1-Score = 0.7444
# Predictions using patient age = 55 have F1-Score = 0.7636
# Predictions using patient age = 60 have F1-Score = 0.7875
# Predictions using patient age = 65 have F1-Score = 0.7947
# Predictions using patient age = 70 have F1-Score = 0.8000
# Predictions using patient age = 75 have F1-Score = 0.7886

# %%
accs_age50 = [accuracy_score(labels_age50,np.round(pr)) for pr in predictions_age50]
for i in zip(range(20,80,5), accs_age50):
    print("Predictions using patient age = {} have Accuracy = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have Accuracy = 0.6687
# Predictions using patient age = 25 have Accuracy = 0.6875
# Predictions using patient age = 30 have Accuracy = 0.7094
# Predictions using patient age = 35 have Accuracy = 0.7406
# Predictions using patient age = 40 have Accuracy = 0.7719
# Predictions using patient age = 45 have Accuracy = 0.7750
# Predictions using patient age = 50 have Accuracy = 0.7875
# Predictions using patient age = 55 have Accuracy = 0.7969
# Predictions using patient age = 60 have Accuracy = 0.8094
# Predictions using patient age = 65 have Accuracy = 0.8063
# Predictions using patient age = 70 have Accuracy = 0.8063
# Predictions using patient age = 75 have Accuracy = 0.7906

# %%
baccs_age50 = [balanced_accuracy_score(labels_age50,np.round(pr)) for pr in predictions_age50]
for i in zip(range(20,80,5), baccs_age50):
    print("Predictions using patient age = {} have Balanced Accuracy = {:.4f}".format(i[0],i[1]))
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.6606
# Predictions using patient age = 25 have Balanced Accuracy = 0.6800
# Predictions using patient age = 30 have Balanced Accuracy = 0.7024
# Predictions using patient age = 35 have Balanced Accuracy = 0.7344
# Predictions using patient age = 40 have Balanced Accuracy = 0.7665
# Predictions using patient age = 45 have Balanced Accuracy = 0.7700
# Predictions using patient age = 50 have Balanced Accuracy = 0.7838
# Predictions using patient age = 55 have Balanced Accuracy = 0.7939
# Predictions using patient age = 60 have Balanced Accuracy = 0.8073
# Predictions using patient age = 65 have Balanced Accuracy = 0.8053
# Predictions using patient age = 70 have Balanced Accuracy = 0.8060
# Predictions using patient age = 75 have Balanced Accuracy = 0.7909

# %%
for pr in predictions_age50:
    fpr, tpr, threshold = roc_curve(labels_age50,pr)
    plt.plot(fpr, tpr)
plt.ylim(0,1);
plt.xlim(0,1);
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.savefig('test-auc-reduced-testset.png')

# %%
fpr, tpr, threshold = roc_curve(labels_age50,predictions_age50[8])
print(fpr[20], tpr[20], threshold[20])
# Out:
# 0.10975609756097561 0.7243589743589743 0.50254226

# %%
for pr in predictions_age50:
    precision, recall, _ = precision_recall_curve(labels_age50, pr)
    plt.step(recall, precision,where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.savefig('test-precision-recall-reduced-testset.png')

# %%
precision, recall, threshold = precision_recall_curve(labels_age50, predictions_age50[8])
print(precision[166], recall[166], threshold[166])
# Out:
# 0.8625954198473282 0.7243589743589743 0.50254226

# %% [markdown]
# ## Subconjunto de indivíduos com diagnósticos diferentes ao longo das visitas

# %%
df_var = pd.read_csv("../datasets/visits_checked_changed_test_positivo_1000_random_0.csv").groupby('id').mean()
df_var = df_var[(df_var.T2D > 0.0) & (df_var.T2D < 1.0)]
features_var = df_var[c].values
labels_var = df_var['T2D'].values

# %%
df_var
# Out:
#         snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# id
# A00161              0.0             0.0             0.0             0.0
# A00165              0.0             1.0             0.0             0.0
# A00235              0.0             0.0             0.0             0.0
# A00291              0.0             2.0             0.0             1.0
# A00486              0.0             0.0             0.0             0.0
# ...                 ...             ...             ...             ...
# A39067              0.0             2.0             0.0             0.0
# A44008              0.0             2.0             0.0             1.0
# A44092              0.0             0.0             0.0             0.0
# A44205              0.0             0.0             0.0             0.0
# A46038              0.0             0.0             0.0             0.0
#
#         snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# id
# ...

# %%
predictions_var = [[np.median(pred.patient(f, age=age)) for f in features_var] for age in range(20,90,5)]

# %%
neg_life = pred.negatives_life(samples=100)

# %%
plt.figure(figsize=(16,8))
plt.subplot(121)
sns.boxplot(data = predictions_var);
plt.xlabel("patient")
plt.ylim(0,1);
plt.subplot(122)
sns.boxplot(x=[i for i in neg_life[1]], y=neg_life[0], showfliers=False);
plt.xlabel("negatives\n(age >= 60)")
plt.ylim(0,1);
# plt.savefig("negative-lifetime-boxplots.png")

# %%
plt.plot(predictions_var);
plt.ylim(0,1);

# %% [markdown]
# # Analise da idade que o paciente desenvolveu

# %%
# df_visits = pd.read_csv("../datasets/visits_checked_changed_test_positivo_1000_random_0.csv").groupby('id').agg(
#     first_age=('AGE', 'first'),
#     last_age=('AGE', 'last'),
#     first_T2D=('T2D', 'first'),
#     last_T2D=('T2D', 'last')
# )
# df_visits = df_var[c[:-1]].join(df_visits)
# df_visits = df_visits[(df_visits["first_T2D"] == 0) & (df_visits["last_T2D"] == 1)]
# # df_visits = df_visits[df_visits.index.isin(df_var.index)]
# features_first_visit = df_visits[c[:-1]+["first_age"]].values
# labels_first_visit = df_visits["first_T2D"].values
# features_last_visit = df_visits[c[:-1]+["last_age"]].values
# labels_last_visit = df_visits["last_T2D"].values

# %%
df_visits = pd.read_csv("../datasets/visits_checked_changed_test_positivo_1000_random_0.csv").sort_values(['id','AGE'])
df_sel_first_last = df_visits.groupby('id').agg(
    first_age=('AGE', 'first'),
    last_age=('AGE', 'last'),
    first_T2D=('T2D', 'first'),
    last_T2D=('T2D', 'last')
)
df_sel_valid = df_sel_first_last[(df_sel_first_last['first_T2D']==0) & (df_sel_first_last['last_T2D']==1)]
df_first_diag = df[df.index.isin(df_sel_valid.index)]
features_first_diag = df_first_diag[c].values
labels_first_diag = df_first_diag['T2D'].values

# %%
predictions_first_diag = [np.median(pred.patient(f, age=-1)) for f in features_first_diag]

# %%
# predictions_last_visit = [np.median(pred.patient(f, age=-1)) for f in features_last_visit]

# %%
# predictions_first_visit = [np.median(pred.patient(f, age=-1)) for f in features_first_visit]

# %%
plt.scatter(y=predictions_first_diag, x=features_first_diag[:,-1], color="red")

# %%
predictions_visits = [[np.median(pred.patient(f, age=age)) for f in features_first_diag] for age in range(20,90,5)]

# %%
plt.plot(predictions_visits);
plt.scatter(y=predictions_first_diag, x=(features_first_diag[:,-1]-20)/5, color="red")
plt.ylim(0,1);

# %%
plt.figure(figsize=(8,6))
plt.plot(predictions_visits);
plt.scatter(y=predictions_first_diag, x=(features_first_diag[:,-1]-20)/5, color="black", zorder=3)
sns.boxplot(x=[i for i in neg_life[1]], y=neg_life[0], showfliers=False);
plt.ylim(0,1);
plt.hlines(0.5,0,13, linestyles='dotted')
plt.xlabel("Age")
plt.ylabel("Predicted probability")
plt.savefig("probability-age-visits-patients.png")

# %%
predictions_visit_30 = [np.median(pred.patient(f, age=30)) for f in features_first_diag]

# %%
plt.scatter(y=features_first_diag[:,-1], x=predictions_visit_30, zorder=2)
# sns.kdeplot(predictions_visit_30, features_last_visit[:,-1], cmap="Blues", shade=True, shade_lowest=False)
coef = np.polyfit(predictions_visit_30,features_first_diag[:,-1],1)
poly1d_fn = np.poly1d(coef)
print(coef)
plt.plot(predictions_visit_30, features_first_diag[:,-1], 'ko', predictions_visit_30, poly1d_fn(predictions_visit_30), 'r')
plt.xlim(0,1)
plt.xlabel("Predicted probability (30yo)")
plt.ylabel("Patient age at first positive diagnostic")
plt.savefig("prob-at-30Xage-first-positive.png")
# Out:
# [-13.90270116  58.74147764]

# %%
from scipy.stats import spearmanr
spearmanr(predictions_visit_30, features_first_diag[:,-1])
# Out:
# SpearmanrResult(correlation=-0.2641686671537418, pvalue=0.032085425535557106)

# %% [markdown]
# ### Dos indivíduos onde foi observado uma mudança do diagnóstico ao longo das visitas, apenas dois deles tem valores de predição selemelhantes aos negativos.

# %%
print("Os dois indivíduos que tiveram predição \"negativa\" foram: {} e {}".format(df_var.iloc[2].name,  df_var.iloc[34].name))
plt.plot(np.array(predictions_var)[:,[2,34]]);
# plt.plot(np.array(predictions_var)[:,23]);
plt.ylim(0,1);
# Out:
# Os dois indivíduos que tiveram predição "negativa" foram: A00228 e A22168

# %% [markdown]
# Um deles, o A00228, aparentemente desenvolveu diabetes após os 63 anos de idade.

# %%
df_raw = pd.read_csv("../datasets/visits_new_test_positivo_1000_random_0.csv")
df_raw[df_raw.id == 'A00228']
# Out:
#          id  snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# 361  A00228                0               0               0               0
# 362  A00228                0               0               0               0
# 363  A00228                0               0               0               0
#
#      snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# 361                0               0               0                0
# 362                0               0               0                0
# 363                0               0               0                0
#
#      snp_18_56742728  ...  snp_6_37571581  snp_20_52032232  snp_20_52032233  \
# 361                0  ...               0                0                0
# 362                0  ...               0                0                0
# 363                0  ...               0                0                0
#
# ...

# %% [markdown]
# Quanto ao outro, o A22168, não sabemos quando o período de desenvolvimento da doença. No entanto, chamou nossa atenção o BMI de 44.16.

# %%
df_raw[df_raw.id == 'A22168']
# Out:
#         id  snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# 76  A22168                0               0               0               0
# 77  A22168                0               0               0               0
# 78  A22168                0               0               0               0
#
#     snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# 76                0               0               0                0
# 77                0               0               0                0
# 78                0               0               0                0
#
#     snp_18_56742728  ...  snp_6_37571581  snp_20_52032232  snp_20_52032233  \
# 76                0  ...               0                0                0
# 77                0  ...               0                0                0
# 78                0  ...               0                0                0
#
#     snp_20_26104019  snp_20_50189624  snp_1_143276644  snp_16_9536673  \
# ...

# %%
df_bmi = pd.read_csv("../../../../data_26_09_2019/T2D_BMI_AGE.csv")

# %%
df_bmi[df_bmi.id == "A00228"]
# Out:
#          id    AGE    BMI  T2D
# 787  A00228  68.85  25.33  1.0

# %%
df_bmi[df_bmi.id == "A22168"]
# Out:
#           id       AGE    BMI  T2D
# 2754  A22168  78.54073  44.16  1.0

# %% [markdown]
# ## Jovens negativos

# %%
df_young = df[(df.T2D < 0.5) & (df.AGE < 50)]
features_young = df_young[c].values
labels_young = df_young['T2D'].values

# %%
df_young
# Out:
#         snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# id
# A00162                0               0               0               0
# A00163                0               0               0               0
# A00164                0               0               0               0
# A00204                0               0               0               0
# A00205                0               0               0               0
# ...                 ...             ...             ...             ...
# A44179                0               0               0               0
# A44181                0               0               0               0
# A44182                0               0               0               1
# A44223                0               2               0               1
# A46054                0               2               0               0
#
#         snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# id
# ...

# %%
plt.boxplot(df_young["AGE"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0ce69f4208>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0ce69f4e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0ce69f4f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0ce69e6198>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0ce69e6390>],
#  'means': []}

# %%
predictions_young = [[np.median(pred.patient(f, age=age)) for f in features_young] for age in range(20,90,5)]
predictions_young_age = [np.median(pred.patient(f, age=-1)) for f in features_young]

# %%
plt.plot(predictions_young);
plt.ylim(0,1);

# %%
young_ind = np.array(predictions_young)
b = young_ind[8] > 0.5
plt.plot(young_ind[:,b], );
plt.scatter(y=np.array(predictions_young_age)[b], x=(np.array(features_young)[b,-1]-20)/5, color="black", zorder=3, marker='*')
sns.boxplot(x=[i for i in neg_life[1]], y=neg_life[0], showfliers=False);
plt.ylim(0,1);
# plt.savefig("pred-pos-young-negatives.png")

# %%
young_ind = np.array(predictions_young)
nb = young_ind[8] < 0.5
plt.plot(young_ind[:,nb], color="grey", alpha=0.2);
plt.scatter(y=np.array(predictions_young_age)[nb], x=(np.array(features_young)[nb,-1]-20)/5, color="black", zorder=3, marker='+')
sns.boxplot(x=[i for i in neg_life[1]], y=neg_life[0], showfliers=False);
plt.ylim(0,1);
# plt.savefig("pred-neg-young-negatives.png")

# %%
plt.scatter(y=predictions_young_age, x=features_young[:,-1])

# %%
predictions_young_55 = [np.median(pred.patient(f, age=60)) for f in features_young]

# %%
plt.bar([0,1],[sum(np.array(predictions_young_55) < 0.5), sum(np.array(predictions_young_55) > 0.5)], color=["tab:blue", "tab:red"])
plt.xticks(np.arange(2), ('Negative', 'Positive'))
plt.text(x=-0.1,y=175,s="84.8%", size=18, color="white")
plt.text(x=0.90,y=15,s="15.2%", size=18, color="white")
# plt.savefig("proportion-positives-in-young-negatives.png")
# plt.xticks(["P", "N"])
# Out:
# Text(0.9, 15, '15.2%')

# %%
sum(np.array(predictions_young_55) > 0.5)/len(np.array(predictions_young_55) < 0.5)
# Out:
# 0.15217391304347827

# %%
ind_bmi = np.array(predictions_young_55) > 0.8
np.array(df_young.index)[ind_bmi]
# Out:
# array(['A04009', 'A04070', 'A06147', 'A09037', 'A16055', 'A21089',
#        'A21105', 'A23023', 'A29028', 'A29083', 'A32020', 'A36051',
#        'A39008', 'A42001'], dtype=object)

# %%
df_young.loc['A04070']
# Out:
# snp_8_133462953     0.00
# snp_2_91635413      0.00
# snp_9_25963828      0.00
# snp_1_17764169      0.00
# snp_12_41767967     0.00
#                    ...
# snp_1_143276644     0.00
# snp_16_9536673      0.00
# snp_20_25734788     0.00
# AGE                49.36
# T2D                 0.00
# Name: A04070, Length: 1002, dtype: float64

# %%
df_bmi[df_bmi.id == 'A04070']
# Out:
#          id   AGE    BMI  T2D
# 781  A04070  60.0  23.86  1.0

# %%
sns.barplot(data=[[np.array(predictions_young_55) < 0.5], [np.array(predictions_young_55) > 0.5]], ci=None)
plt.xticks(np.arange(2), ('Negative', 'Positive'))
# Out:
# ([<matplotlib.axis.XTick at 0x7fe4251d6cf8>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
sns.barplot(data=[[np.array(labels) < 0.5], [np.array(labels) > 0.5]], ci=None)
plt.xticks(np.arange(5), ('Tom', 'Dick', 'Harry', 'Sally', 'Sue'))
# Out:
# ([<matplotlib.axis.XTick at 0x7fe424d224e0>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
plt.boxplot(df_var.AGE)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f82ef2b3f60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f82ef2b3710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f82ec115ba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f82d7eecda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f82ef2a56d8>],
#  'means': []}

# %%
df[df.T2D > 0.5]
# Out:
#         snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# id
# A00012                0               0               0               0
# A00144                0               0               0               0
# A00158                0               0               0               0
# A00165                0               1               0               0
# A00181                0               0               0               0
# ...                 ...             ...             ...             ...
# A46001                0               2               1               1
# A46006                0               2               1               1
# A46007                0               2               1               1
# A46057                0               1               0               1
# A47001                0               2               0               1
#
#         snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# id
# ...

# %%
roc_auc_score(labels, np.random.binomial(1,0.25,488))
# Out:
# 0.47274305555555557

# %%
len(labels, np.random.binomial(1,0.25,488))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-7d73114ae412> in <module>
# ----> 1 len(labels, np.random.binomial(1,0.25,488))
#
# TypeError: len() takes exactly one argument (2 given)

# %%
sum(np.random.binomial(1,0.25,488))
# Out:
# 124

# %%
df_age50
# Out:
#         snp_8_133462953  snp_2_91635413  snp_9_25963828  snp_1_17764169  \
# id
# A00012                0               0               0               0
# A00144                0               0               0               0
# A00158                0               0               0               0
# A00165                0               1               0               0
# A00166                0               0               0               0
# ...                 ...             ...             ...             ...
# A46001                0               2               1               1
# A46006                0               2               1               1
# A46007                0               2               1               1
# A46057                0               1               0               1
# A47001                0               2               0               1
#
#         snp_12_41767967  snp_4_49530811  snp_2_96519717  snp_7_116910447  \
# id
# ...
