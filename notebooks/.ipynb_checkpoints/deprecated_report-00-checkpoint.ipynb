# %%
import report

# %%
r = report.DiabNetReport("../diabnet/models/teste-sp-soft-label_tmp.pth", "positivo_1000_random_0.csv")
# r = report.DiabNetReport("../model_test.pth", "positivo_1000_random_0.csv")

# %%
r.auc()
r.f1()
r.acc()
r.bacc()
# Out:
# AUC = 0.8990
# F1-Score = 0.7106
# Accuracy = 0.8164
# Balanced Accuracy = 0.8099

# %%
r.auc_per_age()
# Out:
# Predictions using patient age = 20 have AUC = 0.8948
# Predictions using patient age = 25 have AUC = 0.8974
# Predictions using patient age = 30 have AUC = 0.8966
# Predictions using patient age = 35 have AUC = 0.8979
# Predictions using patient age = 40 have AUC = 0.8999
# Predictions using patient age = 45 have AUC = 0.9002
# Predictions using patient age = 50 have AUC = 0.9002
# Predictions using patient age = 55 have AUC = 0.9014
# Predictions using patient age = 60 have AUC = 0.8993
# Predictions using patient age = 65 have AUC = 0.8970
# Predictions using patient age = 70 have AUC = 0.8996
# Predictions using patient age = 75 have AUC = 0.8961

# %%
r.f1_per_age()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6875
# Predictions using patient age = 25 have F1-Score = 0.6920
# Predictions using patient age = 30 have F1-Score = 0.7033
# Predictions using patient age = 35 have F1-Score = 0.6942
# Predictions using patient age = 40 have F1-Score = 0.7097
# Predictions using patient age = 45 have F1-Score = 0.7212
# Predictions using patient age = 50 have F1-Score = 0.7216
# Predictions using patient age = 55 have F1-Score = 0.7166
# Predictions using patient age = 60 have F1-Score = 0.7026
# Predictions using patient age = 65 have F1-Score = 0.6667
# Predictions using patient age = 70 have F1-Score = 0.6501
# Predictions using patient age = 75 have F1-Score = 0.6388

# %%
r.acc_per_age()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.8545
# Predictions using patient age = 25 have Accuracy = 0.8527
# Predictions using patient age = 30 have Accuracy = 0.8527
# Predictions using patient age = 35 have Accuracy = 0.8382
# Predictions using patient age = 40 have Accuracy = 0.8364
# Predictions using patient age = 45 have Accuracy = 0.8327
# Predictions using patient age = 50 have Accuracy = 0.8218
# Predictions using patient age = 55 have Accuracy = 0.8073
# Predictions using patient age = 60 have Accuracy = 0.7891
# Predictions using patient age = 65 have Accuracy = 0.7436
# Predictions using patient age = 70 have Accuracy = 0.7182
# Predictions using patient age = 75 have Accuracy = 0.7018

# %%
r.bacc_per_age()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7668
# Predictions using patient age = 25 have Balanced Accuracy = 0.7714
# Predictions using patient age = 30 have Balanced Accuracy = 0.7810
# Predictions using patient age = 35 have Balanced Accuracy = 0.7806
# Predictions using patient age = 40 have Balanced Accuracy = 0.7967
# Predictions using patient age = 45 have Balanced Accuracy = 0.8116
# Predictions using patient age = 50 have Balanced Accuracy = 0.8195
# Predictions using patient age = 55 have Balanced Accuracy = 0.8229
# Predictions using patient age = 60 have Balanced Accuracy = 0.8160
# Predictions using patient age = 65 have Balanced Accuracy = 0.7920
# Predictions using patient age = 70 have Balanced Accuracy = 0.7801
# Predictions using patient age = 75 have Balanced Accuracy = 0.7706

# %%
r.roc_curves()

# %%
r.precision_recall_curves()

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.8773
# F1-Score = 0.7702
# Accuracy = 0.7688
# Balanced Accuracy = 0.7694

# %%
r.auc_per_age_older50()
r.f1_per_age_older50()
r.acc_per_age_older50()
r.bacc_per_age_older50()
# Out:
# Predictions using patient age = 20 have AUC = 0.9208
# Predictions using patient age = 25 have AUC = 0.9208
# Predictions using patient age = 30 have AUC = 0.9185
# Predictions using patient age = 35 have AUC = 0.9190
# Predictions using patient age = 40 have AUC = 0.9158
# Predictions using patient age = 45 have AUC = 0.9157
# Predictions using patient age = 50 have AUC = 0.9165
# Predictions using patient age = 55 have AUC = 0.9146
# Predictions using patient age = 60 have AUC = 0.9109
# Predictions using patient age = 65 have AUC = 0.9069
# Predictions using patient age = 70 have AUC = 0.9064
# Predictions using patient age = 75 have AUC = 0.9041
# Predictions using patient age = 20 have F1-Score = 0.7073
# Predictions using patient age = 25 have F1-Score = 0.7331
# Predictions using patient age = 30 have F1-Score = 0.7413
# Predictions using patient age = 35 have F1-Score = 0.7687
# Predictions using patient age = 40 have F1-Score = 0.7845
# Predictions using patient age = 45 have F1-Score = 0.8081
# Predictions using patient age = 50 have F1-Score = 0.8247
# Predictions using patient age = 55 have F1-Score = 0.8297
# Predictions using patient age = 60 have F1-Score = 0.8071
# Predictions using patient age = 65 have F1-Score = 0.8174
# Predictions using patient age = 70 have F1-Score = 0.8113
# Predictions using patient age = 75 have F1-Score = 0.8033
# Predictions using patient age = 20 have Accuracy = 0.7750
# Predictions using patient age = 25 have Accuracy = 0.7906
# Predictions using patient age = 30 have Accuracy = 0.7906
# Predictions using patient age = 35 have Accuracy = 0.8063
# Predictions using patient age = 40 have Accuracy = 0.8094
# Predictions using patient age = 45 have Accuracy = 0.8219
# Predictions using patient age = 50 have Accuracy = 0.8313
# Predictions using patient age = 55 have Accuracy = 0.8281
# Predictions using patient age = 60 have Accuracy = 0.7969
# Predictions using patient age = 65 have Accuracy = 0.8031
# Predictions using patient age = 70 have Accuracy = 0.7906
# Predictions using patient age = 75 have Accuracy = 0.7781
# Predictions using patient age = 20 have Balanced Accuracy = 0.7697
# Predictions using patient age = 25 have Balanced Accuracy = 0.7857
# Predictions using patient age = 30 have Balanced Accuracy = 0.7864
# Predictions using patient age = 35 have Balanced Accuracy = 0.8027
# Predictions using patient age = 40 have Balanced Accuracy = 0.8070
# Predictions using patient age = 45 have Balanced Accuracy = 0.8206
# Predictions using patient age = 50 have Balanced Accuracy = 0.8308
# Predictions using patient age = 55 have Balanced Accuracy = 0.8289
# Predictions using patient age = 60 have Balanced Accuracy = 0.7987
# Predictions using patient age = 65 have Balanced Accuracy = 0.8056
# Predictions using patient age = 70 have Balanced Accuracy = 0.7939
# Predictions using patient age = 75 have Balanced Accuracy = 0.7818

# %%
r.roc_curves_older50()

# %%
r.precision_recall_curves_older50()

# %%
r.family_plots()

# %%
r.parents_plots()

# %%
r.dataset_test_first_diag.df.sort_values(by='AGE')
# Out:
#      Unnamed: 0      id  snp_8_133462953  snp_2_91635413  snp_9_25963828  \
# 50          128  A01561                0               0               0
# 152         368  A01036                0               0               0
# 132         317  A29031                0               0               0
# 51          129  A01561                0               0               0
# 94          229  A00567                0               0               0
# ..          ...     ...              ...             ...             ...
# 59          150  A01673                0               0               1
# 39          107  A13027                0               0               0
# 159         383  A02287                0               0               0
# 110         262  A16023                0               0               0
# 111         263  A16023                0               0               0
#
#      snp_1_17764169  snp_12_41767967  snp_4_49530811  snp_2_96519717  \
# 50                0                0               0               0
# 152               0                0               0               0
# 132               0                0               0               0
# 51                0                0               0               0
# 94                0                0               0               1
# ..              ...              ...             ...             ...
# 59                0                0               0               0
# 39                0                0               0               0
# 159               0                0               0               0
# 110               0                0               0               0
# 111               0                0               0               0
#
#      snp_7_116910447  ...  snp_1_143276644  snp_16_9536673  snp_20_25734788  \
# 50                 0  ...                0               0                0
# 152                0  ...                0               0                0
# 132                0  ...                0               0                0
# 51                 0  ...                0               0                0
# 94                 0  ...                1               0                1
# ..               ...  ...              ...             ...              ...
# 59                 0  ...                0               0                0
# 39                 0  ...                0               0                0
# 159                1  ...                0               0                0
# 110                0  ...                0               0                0
# 111                0  ...                0               0                0
#
#      AGE  T2D  sex      mo      fa  mo_t2d  fa_t2d
# 50    20    0    M  A11105  A11176     0.0     2.0
# 152   21    0    M  A00486  A09127     1.0     2.0
# 132   23    0    M  A29001  A29002     0.0     0.0
# 51    25    1    M  A11105  A11176     0.0     2.0
# 94    25    0    M  A00565  A05015     0.0     0.0
# ..   ...  ...  ...     ...     ...     ...     ...
# 59    72    1    F  A14021  A14014     2.0     2.0
# 39    74    1    M       0       0     2.0     2.0
# 159   75    1    F  A21040  A21047     2.0     2.0
# 110   81    0    M  A16050  A16021     2.0     2.0
# 111   85    1    M  A16050  A16021     2.0     2.0
#
# [172 rows x 1009 columns]

# %%
r.dataset_test_first_diag.df.boxplot(column='AGE', by='T2D')
