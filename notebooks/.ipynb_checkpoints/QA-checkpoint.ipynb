# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import report_ensemble
from diabnet.ensemble import Ensemble
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
colors = sns.color_palette("colorblind")
sns.palplot(colors)
sns.set_palette(colors)
# sns.set_style("whitegrid")
sns.set_style("ticks",{'axes.grid': True,'grid.color': '.95', 'grid.linestyle': '-'})
sns.set_context("paper")

# %%
ensemble = Ensemble('../data/models/model-positive-13-adamw-lc5-2021-03-03')
r = report_ensemble.DiabNetReport(ensemble, "positivo_1000_random_0.csv")
# Out:
# ../data/models/model-positive-13-adamw-lc5-2021-03-03
# NEGATIVE FILE ../data/datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
df = pd.DataFrame(r.dataset_test_unique.features)
df.columns = r.feat_names
df['T2D'] = r.dataset_test_unique.labels
df['Pred'] = r.dataset_test_unique.predictions

# %% [markdown]
# ## Por que alguns pacientes diabéticos não são identificados?
#
# Quais caracerísticas diferem "true positives" de "false negatives"?
#
# **Hipótese:** Os "false negatives" tem maior contribuição ambiental e menor contribuição genética.
#
# *Possíveis pistas:*
# - Frequência no diagnóstico dos pais.
# - Idade
# - BMI
# - ~Sexo~

# %%
df0 = df[df.T2D == 1]
df0 = df0[['AGE','sex','mo_t2d', 'fa_t2d', 'Pred']]
# df0['positives'] = df0.Pred < .5 
df0['positives'] = ["FN" if x else "TP" for x in df0.Pred < .5]

# %%
df0[df0.positives == 'TP']
# Out:
#     AGE sex mo_t2d fa_t2d      Pred positives
# 0    51   M      2      2  0.901883        TP
# 5    53   F      1      1  0.950532        TP
# 6    39   F      2      0  0.984949        TP
# 13   40   F      2      1  0.592947        TP
# 15   28   F      0      2  0.714250        TP
# ..   ..  ..    ...    ...       ...       ...
# 534  44   F      2      2  0.665578        TP
# 540  52   M      2      2  0.601046        TP
# 541  38   F      1      1  0.643450        TP
# 542  54   F      2      2  0.960101        TP
# 549  30   F      1      2  0.987017        TP
#
# [112 rows x 6 columns]

# %%
df0
# Out:
#     AGE sex mo_t2d fa_t2d      Pred positives
# 0    51   M      2      2  0.901883        TP
# 2    52   F      0      2  0.422955        FN
# 5    53   F      1      1  0.950532        TP
# 6    39   F      2      0  0.984949        TP
# 13   40   F      2      1  0.592947        TP
# ..   ..  ..    ...    ...       ...       ...
# 539  53   F      1      1  0.420062        FN
# 540  52   M      2      2  0.601046        TP
# 541  38   F      1      1  0.643450        TP
# 542  54   F      2      2  0.960101        TP
# 549  30   F      1      2  0.987017        TP
#
# [156 rows x 6 columns]

# %%
112/156
# Out:
# 0.717948717948718

# %%
plt.figure(dpi=300)
sns.boxplot(y='AGE', x='positives', data=df0)
# Out:
# <AxesSubplot:xlabel='positives', ylabel='AGE'>

# %%
plt.figure( dpi=300)
sns.countplot(x='sex', hue='positives', data=df0)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure( dpi=300)
sns.countplot(x='mo_t2d', hue='positives', data=df0)
# Out:
# <AxesSubplot:xlabel='mo_t2d', ylabel='count'>

# %%
plt.figure( dpi=300)
sns.countplot(x='fa_t2d', hue='positives', data=df0)
# Out:
# <AxesSubplot:xlabel='fa_t2d', ylabel='count'>

# %%
plt.figure( dpi=300)
sns.boxplot(y='AGE', x='mo_t2d',hue='positives', data=df0)
# Out:
# <AxesSubplot:xlabel='mo_t2d', ylabel='AGE'>

# %%
# pd.read_csv("../data/datasets/visits_sp_unique_test_positivo_1000_negative_0.csv")

# %% [markdown]
# ## Qual o perfil dos não diabéticos preditos como diabéticos?

# %% [markdown]
# ........

# %%
df1 = df[df.T2D == 0]
df1 = df1[['AGE','sex','mo_t2d', 'fa_t2d', 'Pred']]
# df0['positives'] = df0.Pred < .5 
df1['negatives'] = ["TN" if x else "FP" for x in df1.Pred < .5]

# %%
df1[df1.negatives == 'FP']
# Out:
#     AGE sex mo_t2d fa_t2d      Pred negatives
# 8    52   F      0      2  0.584978        FP
# 40   63   F      2      2  0.595033        FP
# 83   59   F      0      2  0.561923        FP
# 86   64   F      2      1  0.524197        FP
# 91   35   M      0      2  0.670288        FP
# 98   47   F      1      2  0.598342        FP
# 163  72   M      0      2  0.541461        FP
# 170  74   F      2      2  0.688194        FP
# 198  63   F      2      2  0.559714        FP
# 204  46   F      1      2  0.712089        FP
# 231  53   F      1      2  0.514489        FP
# 236  47   M      2      2  0.766494        FP
# 239  59   F      2      2  0.670419        FP
# 255  42   M      1      1  0.536216        FP
# 284  46   F      1      2  0.507562        FP
# 291  40   F      1      2  0.784522        FP
# 297  54   F      0      2  0.696311        FP
# 301  59   M      0      2  0.568221        FP
# 332  63   F      1      0  0.538815        FP
# 386  31   M      1      2  0.623116        FP
# 389  44   F      0      2  0.596724        FP
# 428  52   F      2      2  0.508419        FP
# 455  59   F      2      2  0.537395        FP
# 461  45   F      2      2  0.595781        FP
# 502  57   F      2      2  0.502595        FP
# 519  53   F      0      2  0.706829        FP
# 524  50   F      2      2  0.670151        FP

# %%
plt.figure( dpi=300)
sns.boxplot(y='AGE', x='negatives', data=df1)
# Out:
# <AxesSubplot:xlabel='negatives', ylabel='AGE'>

# %%
plt.figure( dpi=300)
sns.countplot(x='sex', hue='negatives', data=df1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure( dpi=300)
sns.countplot(x='mo_t2d', hue='negatives', data=df1)
# Out:
# <AxesSubplot:xlabel='mo_t2d', ylabel='count'>

# %%
plt.figure( dpi=300)
sns.countplot(x='fa_t2d', hue='negatives', data=df1)
# Out:
# <AxesSubplot:xlabel='fa_t2d', ylabel='count'>

# %%
df1
# Out:
#     AGE sex mo_t2d fa_t2d      Pred negatives
# 1    40   F      0      1  0.086617        TN
# 3    34   M      0      1  0.034907        TN
# 4    37   F      1      1  0.014082        TN
# 7    61   F      2      2  0.417538        TN
# 8    52   F      0      2  0.584978        FP
# ..   ..  ..    ...    ...       ...       ...
# 544  34   F      0      1  0.011630        TN
# 545  36   M      1      0  0.029540        TN
# 546  41   M      0      2  0.405025        TN
# 547  67   F      2      2  0.064399        TN
# 548  41   F      0      2  0.214895        TN
#
# [394 rows x 6 columns]

# %%
print(f"A porcentagem de falsos positivos é de {len(df1[df1.negatives == 'FP'])/len(df1)*100:.2f}%.")
print(f"A porcentagem de falsos negativos é de {len(df0[df0.positives == 'FN'])/len(df0)*100:.2f}%.")
# Out:
# A porcentagem de falsos positives é de 6.85%.
# A porcentagem de falsos negativos é de 28.21%.

# %% [markdown]
# A maior porcentagem de falsos negativos em relação aos falsos positivos e maior proporção de indivíduos com pais não diabéticos entre os falsos negativos (43.2%) pode ser considerado um indicativo da maior contribuição dos efeitos ambientais nesse grupo.

# %%
df0[(df0.positives == 'FN') & ((df0.mo_t2d == 0)|(df0.mo_t2d == 0))]
# Out:
#     AGE sex mo_t2d fa_t2d      Pred positives
# 2    52   F      0      2  0.422955        FN
# 36   38   F      0      2  0.358166        FN
# 70   26   F      0      2  0.272336        FN
# 82   34   F      0      2  0.177691        FN
# 171  46   F      0      1  0.350553        FN
# 176  25   M      0      2  0.083016        FN
# 193  25   M      0      0  0.121909        FN
# 226  41   F      0      2  0.469782        FN
# 263  32   F      0      2  0.244307        FN
# 329  31   M      0      0  0.258174        FN
# 384  42   M      0      2  0.442900        FN
# 399  35   M      0      1  0.338954        FN
# 414  48   M      0      2  0.339184        FN
# 417  36   M      0      1  0.127513        FN
# 418  28   M      0      0  0.169206        FN
# 435  48   F      0      2  0.286862        FN
# 470  30   M      0      0  0.105553        FN
# 474  51   F      0      0  0.299574        FN
# 517  54   M      0      0  0.362651        FN

# %%
len(df0[(df0.positives == 'FN') & ((df0.mo_t2d == 0)|(df0.mo_t2d == 0))])/len(df0[df0.positives == 'FN'])
# Out:
# 0.4318181818181818
