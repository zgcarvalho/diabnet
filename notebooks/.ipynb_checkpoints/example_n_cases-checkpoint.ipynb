# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
sys.path.append("../")
from diabnet.apply_ensemble import Predictor
from diabnet.data import get_feature_names
from diabnet.ensemble import Ensemble

# %%
colors = sns.color_palette("colorblind")
sns.palplot(colors)
sns.set_style("whitegrid")
sns.set_style("ticks",{'axes.grid': True,'grid.color': '.95', 'grid.linestyle': '-'})

# %%
fn = "../datasets/visits_sp_changed_test_positivo_1000_random_0.csv"
def dataset_test_first_diag(fn):
    df = pd.read_csv(fn)
    # seleciona as amostras negativas e agrupa por id pegando a MAIOR idade
    neg  = df[df.T2D == 0][['id','AGE']].groupby('id').max()
    # seleciona as amostras positivas e agrupa por id pegando a MENOR idade
    pos  = df[df.T2D == 1][['id','AGE']].groupby('id').min()
    dtmp = neg.join(pos, lsuffix='_neg', rsuffix='_pos')
    # filtra somente pacientes que a idade negativa < idade positiva
    dtmp = dtmp[dtmp.AGE_neg < dtmp.AGE_pos]
    tmp = pd.concat([pd.DataFrame({'AGE':dtmp.AGE_neg}),pd.DataFrame({'AGE':dtmp.AGE_pos})])
    tmp = tmp.reset_index()
    # Eu odeio a API do pandas!!!
    df = df.merge(tmp, on=['id','AGE'], how="inner")
    return df

df_first = dataset_test_first_diag(fn)
df_unique = pd.read_csv("../datasets/visits_sp_unique_test_positivo_1000_random_0.csv")

# %%
def plot(df, samples): 
    plt.figure(figsize=(16,16), dpi=300)
    color_boxplot = sns.color_palette("cool", n_colors=20)
    plt.subplots_adjust(hspace=0.4, wspace=0.2)
    for i in range(len(samples)):
        ax1=plt.subplot(4, 4, i+1)
        id = samples[i]
        features = df[c].iloc[id].values
        print(features.shape)
        label = df["T2D"].iloc[id]
        age = features[-4]; age
        probs_life = pred.patient_life(features, samples_per_model=1)
        color_boxplot = sns.color_palette("cool", n_colors=20)
        plt.title(f"patient - id: {df['id'].iloc[id]}\n(age: {age}, diagnostic: {'P' if label==1 else 'N'})")
#         sns.boxplot(x=[i for i in probs_life[1]], y=probs_life[0], showfliers=False, palette=[color_boxplot[int(np.median(a)*20)] for a in probs_life[0]]);
        
        bp2 = plt.boxplot(probs_life[0], showfliers=False, patch_artist=True, labels=[i for i in probs_life[1]], medianprops=dict(linewidth=2.5, color='black'))
        colors = [color_boxplot[int(np.median(a)*20)] for a in probs_life[0]]
        for box, color in zip(bp2['boxes'], colors):
            box.set(facecolor = color)
            box.set(edgecolor = 'black')
        plt.xlabel("age")
        plt.ylim(0,1);

# %%
# ensemble = Ensemble('../diabnet/models/model-11-soft-label-age-positives-1000-dropout0-bn-decay-flood-hyperopt-ax-batch256-radam-lc1-20200918')
ensemble = Ensemble('../diabnet/models/model-4-soft-label-age-positives-500-dropout0-bn-decay-flood-hyperopt-ax-batch256-adamw-lc2-20201001')
c = get_feature_names("../datasets/visits_sp_unique_test_positivo_1000_random_0.csv", BMI=False, sex=True, parents_diagnostics=True)
pred = Predictor(ensemble, c, "../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv")
# Out:
# ../diabnet/models/model-4-soft-label-age-positives-500-dropout0-bn-decay-flood-hyperopt-ax-batch256-adamw-lc2-20201001
# NEGATIVE FILE ../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
# true negatives are people older than 60 and negative
neg_life = pred.negatives_life(samples_per_model=1)

# %% [markdown]
# # Estudo de amostras
#
# Nesse notebook avaliaremos C tipos com N indivíduos para entender o comportamento do classificador. Os tipos são:
#
# - Idosos e positivos.
# - Idosos e negativos.
# - Jovens e positivos.
# - Jovens e negativos.

# %%
feat = df_first[(df_first.id=="A30128")&(df.AGE>60)]
feat = feat[c].values
pred.patient_life(feat, samples_per_model=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-0f1013ff4316> in <module>
#       1 feat = df_first[(df_first.id=="A30128")&(df.AGE>60)]
#       2 feat = feat[c].values
# ----> 3 pred.patient_life(feat, samples_per_model=1)
#
# ~/projects/diabnet/diabnet/apply_ensemble.py in patient_life(self, feat, age_range, bmi, samples_per_model)
#      63         probs_by_age = []
#      64         for age in age_range:
# ---> 65             probs_by_age.append(self.patient(feat, age, bmi, samples_per_model))
#      66         return probs_by_age, age_range
#      67
#
# ~/projects/diabnet/diabnet/apply_ensemble.py in patient(self, feat, age, bmi, samples_per_model)
#      40
#      41         # pass a copy of feature to NOT change original features
# ---> 42         features = self._encode_features(np.copy(feat), age=age, bmi=bmi)
#      43         return self._sampler(features, samples_per_model)
#      44
#
# ~/projects/diabnet/diabnet/apply_ensemble.py in _encode_features(self, feat, age, bmi)
#      83         if age >= 0:
#      84             age_idx = self.feat_names.index('AGE')
# ---> 85             feat[age_idx] = age
#      86         if bmi >= 0:
#      87             bmi_idx = self.feat_names.index('BMI')
#
# IndexError: index 1000 is out of bounds for axis 0 with size 1

# %%
N = 16

# %% [markdown]
# ## 1 - Idosos positivos
#
# *primeiro diagnóstico após 60 anos de idade

# %%
# individuos idosos e positivos
df = df_first
samples = np.random.choice(df[(df.T2D==1)&(df.AGE>60)].index, N);samples
plot(df, samples)
# Out:
# [0 0 1 ... 'M' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 1 ... 'F' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 0 ... 'F' 2.0 1.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 1 ... 'F' 2.0 2.0]
# [0 0 0 ... 'F' 2.0 2.0]
# [0 0 0 ... 'M' 2.0 2.0]
# [0 0 1 ... 'M' 1.0 0.0]
# [0 0 0 ... 'F' 1.0 2.0]
# [0 0 1 ... 'M' 2.0 2.0]

# %% [markdown]
# ## 2 - Idosos negativos
#
# *negativos com mais de 60 anos

# %%
# individuos idosos e positivos
df = df_unique
samples = np.random.choice(df[(df.T2D==0)&(df.AGE>60)].index, N);samples
plot(df, samples)

# %% [markdown]
# ## 3 - Jovens positivos
#
# *positivos com menos de 40 anos

# %%
# individuos idosos e positivos
df = df_first
samples = np.random.choice(df[(df.T2D==1)&(df.AGE<40)].index, N);samples
plot(df, samples)

# %% [markdown]
# ## 4 - Jovens negativos
#
# *negativos com menos de 40 anos

# %%
# individuos idosos e positivos
df = df_unique
samples = np.random.choice(df[(df.T2D==0)&(df.AGE<40)].index, N);samples
plot(df, samples)
