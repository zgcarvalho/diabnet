# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import report_ensemble
from diabnet.ensemble import Ensemble

# %%
ensemble = Ensemble('../diabnet/models/model-3-sp-soft-label-positives-5000-dropout0-bn-decay-flood-hyperopt-*')
# Out:
# ../diabnet/models/model-3-sp-soft-label-positives-5000-dropout0-bn-decay-flood-hyperopt-*

# %%
r = report_ensemble.DiabNetReport(ensemble, "positivo_1000_random_0.csv")
# r = report.DiabNetReport("../model_test.pth", "positivo_1000_random_0.csv")
# Out:
# NEGATIVE FILE ../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
r.auc()
r.f1()
r.acc()
r.bacc()
# Out:
# AUC = 0.9001
# F1-Score = 0.7582
# Accuracy = 0.8655
# Balanced Accuracy = 0.8286

# %%
r.auc_per_age()
# Out:
# Predictions using patient age = 20 have AUC = 0.8915
# Predictions using patient age = 25 have AUC = 0.8916
# Predictions using patient age = 30 have AUC = 0.8921
# Predictions using patient age = 35 have AUC = 0.8911
# Predictions using patient age = 40 have AUC = 0.8915
# Predictions using patient age = 45 have AUC = 0.8923
# Predictions using patient age = 50 have AUC = 0.8931
# Predictions using patient age = 55 have AUC = 0.8940
# Predictions using patient age = 60 have AUC = 0.8945
# Predictions using patient age = 65 have AUC = 0.8951
# Predictions using patient age = 70 have AUC = 0.8950
# Predictions using patient age = 75 have AUC = 0.8938

# %%
r.f1_per_age()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6612
# Predictions using patient age = 25 have F1-Score = 0.6798
# Predictions using patient age = 30 have F1-Score = 0.7027
# Predictions using patient age = 35 have F1-Score = 0.7232
# Predictions using patient age = 40 have F1-Score = 0.7286
# Predictions using patient age = 45 have F1-Score = 0.7390
# Predictions using patient age = 50 have F1-Score = 0.7442
# Predictions using patient age = 55 have F1-Score = 0.7477
# Predictions using patient age = 60 have F1-Score = 0.7485
# Predictions using patient age = 65 have F1-Score = 0.7139
# Predictions using patient age = 70 have F1-Score = 0.6997
# Predictions using patient age = 75 have F1-Score = 0.6789

# %%
r.acc_per_age()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.8491
# Predictions using patient age = 25 have Accuracy = 0.8527
# Predictions using patient age = 30 have Accuracy = 0.8600
# Predictions using patient age = 35 have Accuracy = 0.8636
# Predictions using patient age = 40 have Accuracy = 0.8618
# Predictions using patient age = 45 have Accuracy = 0.8600
# Predictions using patient age = 50 have Accuracy = 0.8600
# Predictions using patient age = 55 have Accuracy = 0.8527
# Predictions using patient age = 60 have Accuracy = 0.8473
# Predictions using patient age = 65 have Accuracy = 0.8164
# Predictions using patient age = 70 have Accuracy = 0.8018
# Predictions using patient age = 75 have Accuracy = 0.7782

# %%
r.bacc_per_age()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7495
# Predictions using patient age = 25 have Balanced Accuracy = 0.7617
# Predictions using patient age = 30 have Balanced Accuracy = 0.7764
# Predictions using patient age = 35 have Balanced Accuracy = 0.7925
# Predictions using patient age = 40 have Balanced Accuracy = 0.7990
# Predictions using patient age = 45 have Balanced Accuracy = 0.8113
# Predictions using patient age = 50 have Balanced Accuracy = 0.8171
# Predictions using patient age = 55 have Balanced Accuracy = 0.8275
# Predictions using patient age = 60 have Balanced Accuracy = 0.8334
# Predictions using patient age = 65 have Balanced Accuracy = 0.8137
# Predictions using patient age = 70 have Balanced Accuracy = 0.8055
# Predictions using patient age = 75 have Balanced Accuracy = 0.7929

# %%
r.roc_curves()

# %%
r.roc_ci()

# %%
r.precision_recall_curves()

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.8992
# F1-Score = 0.8000
# Accuracy = 0.8187
# Balanced Accuracy = 0.8169

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.8992
# F1-Score = 0.8000
# Accuracy = 0.8187
# Balanced Accuracy = 0.8169

# %%
r.auc_per_age_older50()
# Out:
# Predictions using patient age = 20 have AUC = 0.9208
# Predictions using patient age = 25 have AUC = 0.9205
# Predictions using patient age = 30 have AUC = 0.9205
# Predictions using patient age = 35 have AUC = 0.9196
# Predictions using patient age = 40 have AUC = 0.9183
# Predictions using patient age = 45 have AUC = 0.9180
# Predictions using patient age = 50 have AUC = 0.9170
# Predictions using patient age = 55 have AUC = 0.9172
# Predictions using patient age = 60 have AUC = 0.9172
# Predictions using patient age = 65 have AUC = 0.9177
# Predictions using patient age = 70 have AUC = 0.9169
# Predictions using patient age = 75 have AUC = 0.9155

# %%
r.f1_per_age_older50()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6778
# Predictions using patient age = 25 have F1-Score = 0.7049
# Predictions using patient age = 30 have F1-Score = 0.7280
# Predictions using patient age = 35 have F1-Score = 0.7568
# Predictions using patient age = 40 have F1-Score = 0.7698
# Predictions using patient age = 45 have F1-Score = 0.7985
# Predictions using patient age = 50 have F1-Score = 0.8116
# Predictions using patient age = 55 have F1-Score = 0.8304
# Predictions using patient age = 60 have F1-Score = 0.8389
# Predictions using patient age = 65 have F1-Score = 0.8208
# Predictions using patient age = 70 have F1-Score = 0.8247
# Predictions using patient age = 75 have F1-Score = 0.8217

# %%
r.acc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.7594
# Predictions using patient age = 25 have Accuracy = 0.7750
# Predictions using patient age = 30 have Accuracy = 0.7875
# Predictions using patient age = 35 have Accuracy = 0.8031
# Predictions using patient age = 40 have Accuracy = 0.8094
# Predictions using patient age = 45 have Accuracy = 0.8281
# Predictions using patient age = 50 have Accuracy = 0.8375
# Predictions using patient age = 55 have Accuracy = 0.8469
# Predictions using patient age = 60 have Accuracy = 0.8500
# Predictions using patient age = 65 have Accuracy = 0.8281
# Predictions using patient age = 70 have Accuracy = 0.8313
# Predictions using patient age = 75 have Accuracy = 0.8250

# %%
r.bacc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7535
# Predictions using patient age = 25 have Balanced Accuracy = 0.7695
# Predictions using patient age = 30 have Balanced Accuracy = 0.7825
# Predictions using patient age = 35 have Balanced Accuracy = 0.7989
# Predictions using patient age = 40 have Balanced Accuracy = 0.8056
# Predictions using patient age = 45 have Balanced Accuracy = 0.8250
# Predictions using patient age = 50 have Balanced Accuracy = 0.8346
# Predictions using patient age = 55 have Balanced Accuracy = 0.8450
# Predictions using patient age = 60 have Balanced Accuracy = 0.8488
# Predictions using patient age = 65 have Balanced Accuracy = 0.8276
# Predictions using patient age = 70 have Balanced Accuracy = 0.8308
# Predictions using patient age = 75 have Balanced Accuracy = 0.8250

# %%
r.roc_curves_older50()

# %%
r.precision_recall_curves_older50()

# %%
# r.family_plots(fig_path="./family_plots.png")

# %%
r.family_plots()

# %%
# r.parents_plots(fig_path="./parents_plots.png")

# %%
r.parents_plots()

# %%
# r.first_positives(fig_path="./distribution_probabilities_curve.png")

# %%
r.first_positives()
