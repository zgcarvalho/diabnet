# %%
import pandas as pd

# %%
pd.read_csv("../data/datasets/visits_sp_unique_train_positivo_1000_random_0.csv")
# Out:
#       Unnamed: 0      id  snp_8_133462953  snp_2_91635413  snp_9_25963828  \
# 0              0  A13186                0               1               0
# 1              1  A04177                0               0               0
# 2              2  A20059                0               2               0
# 3              3  A22024                0               0               0
# 4              4  A24012                0               0               0
# ...          ...     ...              ...             ...             ...
# 1787        1787  A01939                0               0               0
# 1788        1788  834131                0               0               0
# 1789        1789  A07058                0               0               0
# 1790        1790  A16013                0               0               1
# 1791        1791  A47052                0               0               0
#
#       snp_1_17764169  snp_12_41767967  snp_4_49530811  snp_2_96519717  \
# ...

# %%
a = -1

# %%
if a < 0 or a > 20:
    print(True)
# Out:
# True
