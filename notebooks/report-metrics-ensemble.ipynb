# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import report_ensemble
from diabnet.ensemble import Ensemble

# %%
# ensemble = Ensemble('../diabnet/models/model-13-sp-soft-label-positives-2500-dropout0-bn-decay-flood-hyperopt-*')
ensemble = Ensemble('../diabnet/models/model-6-soft-label-age-positives-2500-dropout0-bn-decay-flood-hyperopt-batch256-lc1-20200831')
# Out:
# ../diabnet/models/model-6-soft-label-age-positives-2500-dropout0-bn-decay-flood-hyperopt-batch256-lc1-20200831

# %%
r = report_ensemble.DiabNetReport(ensemble, "positivo_1000_random_0.csv")
# r = report.DiabNetReport("../model_test.pth", "positivo_1000_random_0.csv")
# Out:
# NEGATIVE FILE ../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
r.auc()
r.f1()
r.acc()
r.bacc()
# Out:
# AUC = 0.9387
# F1-Score = 0.7294
# Accuracy = 0.8745
# Balanced Accuracy = 0.7905

# %%
r.auc_per_age()
# Out:
# Predictions using patient age = 20 have AUC = 0.9441
# Predictions using patient age = 25 have AUC = 0.9435
# Predictions using patient age = 30 have AUC = 0.9424
# Predictions using patient age = 35 have AUC = 0.9420
# Predictions using patient age = 40 have AUC = 0.9410
# Predictions using patient age = 45 have AUC = 0.9401
# Predictions using patient age = 50 have AUC = 0.9386
# Predictions using patient age = 55 have AUC = 0.9375
# Predictions using patient age = 60 have AUC = 0.9363
# Predictions using patient age = 65 have AUC = 0.9350
# Predictions using patient age = 70 have AUC = 0.9333
# Predictions using patient age = 75 have AUC = 0.9319

# %%
r.f1_per_age()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.5701
# Predictions using patient age = 25 have F1-Score = 0.5766
# Predictions using patient age = 30 have F1-Score = 0.6174
# Predictions using patient age = 35 have F1-Score = 0.6414
# Predictions using patient age = 40 have F1-Score = 0.6667
# Predictions using patient age = 45 have F1-Score = 0.6748
# Predictions using patient age = 50 have F1-Score = 0.6908
# Predictions using patient age = 55 have F1-Score = 0.7087
# Predictions using patient age = 60 have F1-Score = 0.7308
# Predictions using patient age = 65 have F1-Score = 0.7574
# Predictions using patient age = 70 have F1-Score = 0.7698
# Predictions using patient age = 75 have F1-Score = 0.7820

# %%
r.acc_per_age()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.8273
# Predictions using patient age = 25 have Accuracy = 0.8291
# Predictions using patient age = 30 have Accuracy = 0.8400
# Predictions using patient age = 35 have Accuracy = 0.8455
# Predictions using patient age = 40 have Accuracy = 0.8527
# Predictions using patient age = 45 have Accuracy = 0.8545
# Predictions using patient age = 50 have Accuracy = 0.8600
# Predictions using patient age = 55 have Accuracy = 0.8655
# Predictions using patient age = 60 have Accuracy = 0.8727
# Predictions using patient age = 65 have Accuracy = 0.8800
# Predictions using patient age = 70 have Accuracy = 0.8836
# Predictions using patient age = 75 have Accuracy = 0.8855

# %%
r.bacc_per_age()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.6994
# Predictions using patient age = 25 have Balanced Accuracy = 0.7026
# Predictions using patient age = 30 have Balanced Accuracy = 0.7238
# Predictions using patient age = 35 have Balanced Accuracy = 0.7372
# Predictions using patient age = 40 have Balanced Accuracy = 0.7520
# Predictions using patient age = 45 have Balanced Accuracy = 0.7571
# Predictions using patient age = 50 have Balanced Accuracy = 0.7668
# Predictions using patient age = 55 have Balanced Accuracy = 0.7783
# Predictions using patient age = 60 have Balanced Accuracy = 0.7931
# Predictions using patient age = 65 have Balanced Accuracy = 0.8136
# Predictions using patient age = 70 have Balanced Accuracy = 0.8239
# Predictions using patient age = 75 have Balanced Accuracy = 0.8368

# %%
r.roc_curves()

# %%
r.roc_ci(bootstrap_samples=1000)

# %%
r.precision_recall_ci()

# %%
r.precision_recall_curves()

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.9288
# F1-Score = 0.7440
# Accuracy = 0.8000
# Balanced Accuracy = 0.7950

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.9288
# F1-Score = 0.7440
# Accuracy = 0.8000
# Balanced Accuracy = 0.7950

# %%
r.auc_per_age_older50()
# Out:
# Predictions using patient age = 20 have AUC = 0.9563
# Predictions using patient age = 25 have AUC = 0.9555
# Predictions using patient age = 30 have AUC = 0.9540
# Predictions using patient age = 35 have AUC = 0.9534
# Predictions using patient age = 40 have AUC = 0.9526
# Predictions using patient age = 45 have AUC = 0.9516
# Predictions using patient age = 50 have AUC = 0.9500
# Predictions using patient age = 55 have AUC = 0.9486
# Predictions using patient age = 60 have AUC = 0.9477
# Predictions using patient age = 65 have AUC = 0.9460
# Predictions using patient age = 70 have AUC = 0.9444
# Predictions using patient age = 75 have AUC = 0.9429

# %%
r.f1_per_age_older50()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.5753
# Predictions using patient age = 25 have F1-Score = 0.5818
# Predictions using patient age = 30 have F1-Score = 0.6256
# Predictions using patient age = 35 have F1-Score = 0.6552
# Predictions using patient age = 40 have F1-Score = 0.6835
# Predictions using patient age = 45 have F1-Score = 0.6946
# Predictions using patient age = 50 have F1-Score = 0.7107
# Predictions using patient age = 55 have F1-Score = 0.7287
# Predictions using patient age = 60 have F1-Score = 0.7540
# Predictions using patient age = 65 have F1-Score = 0.7923
# Predictions using patient age = 70 have F1-Score = 0.8106
# Predictions using patient age = 75 have F1-Score = 0.8278

# %%
r.acc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.7094
# Predictions using patient age = 25 have Accuracy = 0.7125
# Predictions using patient age = 30 have Accuracy = 0.7344
# Predictions using patient age = 35 have Accuracy = 0.7500
# Predictions using patient age = 40 have Accuracy = 0.7656
# Predictions using patient age = 45 have Accuracy = 0.7719
# Predictions using patient age = 50 have Accuracy = 0.7812
# Predictions using patient age = 55 have Accuracy = 0.7906
# Predictions using patient age = 60 have Accuracy = 0.8063
# Predictions using patient age = 65 have Accuracy = 0.8313
# Predictions using patient age = 70 have Accuracy = 0.8438
# Predictions using patient age = 75 have Accuracy = 0.8531

# %%
r.bacc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7019
# Predictions using patient age = 25 have Balanced Accuracy = 0.7051
# Predictions using patient age = 30 have Balanced Accuracy = 0.7276
# Predictions using patient age = 35 have Balanced Accuracy = 0.7436
# Predictions using patient age = 40 have Balanced Accuracy = 0.7596
# Predictions using patient age = 45 have Balanced Accuracy = 0.7660
# Predictions using patient age = 50 have Balanced Accuracy = 0.7756
# Predictions using patient age = 55 have Balanced Accuracy = 0.7854
# Predictions using patient age = 60 have Balanced Accuracy = 0.8014
# Predictions using patient age = 65 have Balanced Accuracy = 0.8271
# Predictions using patient age = 70 have Balanced Accuracy = 0.8399
# Predictions using patient age = 75 have Balanced Accuracy = 0.8500

# %%
r.roc_curves_older50()

# %%
r.roc_ci_older50()

# %%
r.precision_recall_curves_older50()

# %%
r.precision_recall_ci_older50()

# %%
r.roc_comp(fig_path="roc_and_roc_older50_comparative_plot.png")

# %%
r.precision_recall_comp(fig_path="pr_and_pr_older50_comparative_plot.png")

# %%
# r.family_plots(fig_path="./family_plots.png")

# %%
r.family_plots()

# %%
# r.parents_plots(fig_path="./parents_plots.png")

# %%
r.parents_plots()

# %%
# r.first_positives(fig_path="./distribution_probabilities_curve.png")

# %%
r.first_positives()

# %%
#r.first_positives_boxen()

# %%
#r.first_positives_violin()
