# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import report_ensemble
from diabnet.ensemble import Ensemble

# %%
# ensemble = Ensemble('../diabnet/models/model-13-sp-soft-label-positives-2500-dropout0-bn-decay-flood-hyperopt-*')
ensemble = Ensemble('../diabnet/models/model-6-soft-label-age-positives-1000-dropout0-bn-decay-flood-hyperopt-batch256-adamw-lc1-20200914')
# Out:
# ../diabnet/models/model-6-soft-label-age-positives-1000-dropout0-bn-decay-flood-hyperopt-batch256-adamw-lc1-20200914

# %%
r = report_ensemble.DiabNetReport(ensemble, "positivo_1000_random_0.csv")
# r = report.DiabNetReport("../model_test.pth", "positivo_1000_random_0.csv")
# Out:
# NEGATIVE FILE ../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
r.auc()
r.f1()
r.acc()
r.bacc()
# Out:
# AUC = 0.9164
# F1-Score = 0.7491
# Accuracy = 0.8709
# Balanced Accuracy = 0.8131

# %%
r.auc_per_age()
# Out:
# Predictions using patient age = 20 have AUC = 0.8865
# Predictions using patient age = 25 have AUC = 0.8928
# Predictions using patient age = 30 have AUC = 0.8968
# Predictions using patient age = 35 have AUC = 0.8999
# Predictions using patient age = 40 have AUC = 0.9022
# Predictions using patient age = 45 have AUC = 0.9036
# Predictions using patient age = 50 have AUC = 0.9052
# Predictions using patient age = 55 have AUC = 0.9061
# Predictions using patient age = 60 have AUC = 0.9079
# Predictions using patient age = 65 have AUC = 0.9088
# Predictions using patient age = 70 have AUC = 0.9091
# Predictions using patient age = 75 have AUC = 0.9084

# %%
r.f1_per_age()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6053
# Predictions using patient age = 25 have F1-Score = 0.6325
# Predictions using patient age = 30 have F1-Score = 0.6498
# Predictions using patient age = 35 have F1-Score = 0.6803
# Predictions using patient age = 40 have F1-Score = 0.7287
# Predictions using patient age = 45 have F1-Score = 0.7361
# Predictions using patient age = 50 have F1-Score = 0.7500
# Predictions using patient age = 55 have F1-Score = 0.7603
# Predictions using patient age = 60 have F1-Score = 0.7532
# Predictions using patient age = 65 have F1-Score = 0.7485
# Predictions using patient age = 70 have F1-Score = 0.7273
# Predictions using patient age = 75 have F1-Score = 0.7166

# %%
r.acc_per_age()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.8364
# Predictions using patient age = 25 have Accuracy = 0.8436
# Predictions using patient age = 30 have Accuracy = 0.8491
# Predictions using patient age = 35 have Accuracy = 0.8582
# Predictions using patient age = 40 have Accuracy = 0.8727
# Predictions using patient age = 45 have Accuracy = 0.8709
# Predictions using patient age = 50 have Accuracy = 0.8727
# Predictions using patient age = 55 have Accuracy = 0.8727
# Predictions using patient age = 60 have Accuracy = 0.8618
# Predictions using patient age = 65 have Accuracy = 0.8509
# Predictions using patient age = 70 have Accuracy = 0.8255
# Predictions using patient age = 75 have Accuracy = 0.8073

# %%
r.bacc_per_age()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7173
# Predictions using patient age = 25 have Balanced Accuracy = 0.7321
# Predictions using patient age = 30 have Balanced Accuracy = 0.7417
# Predictions using patient age = 35 have Balanced Accuracy = 0.7597
# Predictions using patient age = 40 have Balanced Accuracy = 0.7911
# Predictions using patient age = 45 have Balanced Accuracy = 0.7995
# Predictions using patient age = 50 have Balanced Accuracy = 0.8124
# Predictions using patient age = 55 have Balanced Accuracy = 0.8240
# Predictions using patient age = 60 have Balanced Accuracy = 0.8261
# Predictions using patient age = 65 have Balanced Accuracy = 0.8301
# Predictions using patient age = 70 have Balanced Accuracy = 0.8240
# Predictions using patient age = 75 have Balanced Accuracy = 0.8229

# %%
r.roc_curves()

# %%
r.roc_ci(bootstrap_samples=1000)

# %%
r.precision_recall_ci()

# %%
r.precision_recall_curves()

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.9189
# F1-Score = 0.7794
# Accuracy = 0.8125
# Balanced Accuracy = 0.8093

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.9189
# F1-Score = 0.7794
# Accuracy = 0.8125
# Balanced Accuracy = 0.8093

# %%
r.auc_per_age_older50()
# Out:
# Predictions using patient age = 20 have AUC = 0.9117
# Predictions using patient age = 25 have AUC = 0.9172
# Predictions using patient age = 30 have AUC = 0.9206
# Predictions using patient age = 35 have AUC = 0.9239
# Predictions using patient age = 40 have AUC = 0.9255
# Predictions using patient age = 45 have AUC = 0.9266
# Predictions using patient age = 50 have AUC = 0.9287
# Predictions using patient age = 55 have AUC = 0.9296
# Predictions using patient age = 60 have AUC = 0.9308
# Predictions using patient age = 65 have AUC = 0.9315
# Predictions using patient age = 70 have AUC = 0.9309
# Predictions using patient age = 75 have AUC = 0.9300

# %%
r.f1_per_age_older50()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6133
# Predictions using patient age = 25 have F1-Score = 0.6435
# Predictions using patient age = 30 have F1-Score = 0.6609
# Predictions using patient age = 35 have F1-Score = 0.6946
# Predictions using patient age = 40 have F1-Score = 0.7520
# Predictions using patient age = 45 have F1-Score = 0.7674
# Predictions using patient age = 50 have F1-Score = 0.7925
# Predictions using patient age = 55 have F1-Score = 0.8192
# Predictions using patient age = 60 have F1-Score = 0.8227
# Predictions using patient age = 65 have F1-Score = 0.8328
# Predictions using patient age = 70 have F1-Score = 0.8421
# Predictions using patient age = 75 have F1-Score = 0.8375

# %%
r.acc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.7281
# Predictions using patient age = 25 have Accuracy = 0.7438
# Predictions using patient age = 30 have Accuracy = 0.7531
# Predictions using patient age = 35 have Accuracy = 0.7719
# Predictions using patient age = 40 have Accuracy = 0.8063
# Predictions using patient age = 45 have Accuracy = 0.8125
# Predictions using patient age = 50 have Accuracy = 0.8281
# Predictions using patient age = 55 have Accuracy = 0.8469
# Predictions using patient age = 60 have Accuracy = 0.8438
# Predictions using patient age = 65 have Accuracy = 0.8469
# Predictions using patient age = 70 have Accuracy = 0.8500
# Predictions using patient age = 75 have Accuracy = 0.8375

# %%
r.bacc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7212
# Predictions using patient age = 25 have Balanced Accuracy = 0.7372
# Predictions using patient age = 30 have Balanced Accuracy = 0.7468
# Predictions using patient age = 35 have Balanced Accuracy = 0.7660
# Predictions using patient age = 40 have Balanced Accuracy = 0.8013
# Predictions using patient age = 45 have Balanced Accuracy = 0.8082
# Predictions using patient age = 50 have Balanced Accuracy = 0.8243
# Predictions using patient age = 55 have Balanced Accuracy = 0.8436
# Predictions using patient age = 60 have Balanced Accuracy = 0.8413
# Predictions using patient age = 65 have Balanced Accuracy = 0.8453
# Predictions using patient age = 70 have Balanced Accuracy = 0.8493
# Predictions using patient age = 75 have Balanced Accuracy = 0.8380

# %%
r.roc_curves_older50()

# %%
r.roc_ci_older50()

# %%
r.precision_recall_curves_older50()

# %%
r.precision_recall_ci_older50()

# %%
r.roc_comp(fig_path="roc_and_roc_older50_comparative_plot.png")

# %%
r.precision_recall_comp(fig_path="pr_and_pr_older50_comparative_plot.png")

# %%
# r.family_plots(fig_path="./family_plots.png")

# %%
r.family_plots()

# %%
# r.parents_plots(fig_path="./parents_plots.png")

# %%
r.parents_plots()

# %%
# r.first_positives(fig_path="./distribution_probabilities_curve.png")

# %%
r.first_positives()

# %%
#r.first_positives_boxen()

# %%
#r.first_positives_violin()
