# %%
import report

# %%
r = report.DiabNetReport("../diabnet/models/model-sp-soft-label-positives-1000.pth", "positivo_1000_random_0.csv")
# r = report.DiabNetReport("../model_test.pth", "positivo_1000_random_0.csv")
# Out:
# NEGATIVE FILE ../datasets/visits_sp_unique_test_positivo_1000_random_0_negatives_older60.csv

# %%
r.auc()
r.f1()
r.acc()
r.bacc()
# Out:
# AUC = 0.8951
# F1-Score = 0.7228
# Accuracy = 0.8564
# Balanced Accuracy = 0.7971

# %%
r.auc_per_age()
# Out:
# Predictions using patient age = 20 have AUC = 0.8750
# Predictions using patient age = 25 have AUC = 0.8790
# Predictions using patient age = 30 have AUC = 0.8835
# Predictions using patient age = 35 have AUC = 0.8833
# Predictions using patient age = 40 have AUC = 0.8846
# Predictions using patient age = 45 have AUC = 0.8856
# Predictions using patient age = 50 have AUC = 0.8853
# Predictions using patient age = 55 have AUC = 0.8862
# Predictions using patient age = 60 have AUC = 0.8866
# Predictions using patient age = 65 have AUC = 0.8882
# Predictions using patient age = 70 have AUC = 0.8866
# Predictions using patient age = 75 have AUC = 0.8863

# %%
r.f1_per_age()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6053
# Predictions using patient age = 25 have F1-Score = 0.6250
# Predictions using patient age = 30 have F1-Score = 0.6667
# Predictions using patient age = 35 have F1-Score = 0.7045
# Predictions using patient age = 40 have F1-Score = 0.7153
# Predictions using patient age = 45 have F1-Score = 0.7254
# Predictions using patient age = 50 have F1-Score = 0.7133
# Predictions using patient age = 55 have F1-Score = 0.6903
# Predictions using patient age = 60 have F1-Score = 0.6909
# Predictions using patient age = 65 have F1-Score = 0.6879
# Predictions using patient age = 70 have F1-Score = 0.6795
# Predictions using patient age = 75 have F1-Score = 0.6755

# %%
r.acc_per_age()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.8364
# Predictions using patient age = 25 have Accuracy = 0.8364
# Predictions using patient age = 30 have Accuracy = 0.8473
# Predictions using patient age = 35 have Accuracy = 0.8582
# Predictions using patient age = 40 have Accuracy = 0.8582
# Predictions using patient age = 45 have Accuracy = 0.8582
# Predictions using patient age = 50 have Accuracy = 0.8436
# Predictions using patient age = 55 have Accuracy = 0.8255
# Predictions using patient age = 60 have Accuracy = 0.8145
# Predictions using patient age = 65 have Accuracy = 0.8036
# Predictions using patient age = 70 have Accuracy = 0.7873
# Predictions using patient age = 75 have Accuracy = 0.7764

# %%
r.bacc_per_age()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7173
# Predictions using patient age = 25 have Balanced Accuracy = 0.7290
# Predictions using patient age = 30 have Balanced Accuracy = 0.7540
# Predictions using patient age = 35 have Balanced Accuracy = 0.7790
# Predictions using patient age = 40 have Balanced Accuracy = 0.7887
# Predictions using patient age = 45 have Balanced Accuracy = 0.7984
# Predictions using patient age = 50 have Balanced Accuracy = 0.7960
# Predictions using patient age = 55 have Balanced Accuracy = 0.7833
# Predictions using patient age = 60 have Balanced Accuracy = 0.7892
# Predictions using patient age = 65 have Balanced Accuracy = 0.7913
# Predictions using patient age = 70 have Balanced Accuracy = 0.7896
# Predictions using patient age = 75 have Balanced Accuracy = 0.7897

# %%
r.roc_curves()

# %%
r.precision_recall_curves()

# %%
r.auc_older50()
r.f1_older50()
r.acc_older50()
r.bacc_older50()
# Out:
# AUC = 0.8896
# F1-Score = 0.7709
# Accuracy = 0.8031
# Balanced Accuracy = 0.8001

# %%
r.auc_per_age_older50()
# Out:
# Predictions using patient age = 20 have AUC = 0.9064
# Predictions using patient age = 25 have AUC = 0.9078
# Predictions using patient age = 30 have AUC = 0.9071
# Predictions using patient age = 35 have AUC = 0.9089
# Predictions using patient age = 40 have AUC = 0.9094
# Predictions using patient age = 45 have AUC = 0.9058
# Predictions using patient age = 50 have AUC = 0.9059
# Predictions using patient age = 55 have AUC = 0.9040
# Predictions using patient age = 60 have AUC = 0.9043
# Predictions using patient age = 65 have AUC = 0.9022
# Predictions using patient age = 70 have AUC = 0.9014
# Predictions using patient age = 75 have AUC = 0.8981

# %%
r.f1_per_age_older50()
# Out:
# Predictions using patient age = 20 have F1-Score = 0.6316
# Predictions using patient age = 25 have F1-Score = 0.6638
# Predictions using patient age = 30 have F1-Score = 0.6917
# Predictions using patient age = 35 have F1-Score = 0.7331
# Predictions using patient age = 40 have F1-Score = 0.7549
# Predictions using patient age = 45 have F1-Score = 0.7790
# Predictions using patient age = 50 have F1-Score = 0.7754
# Predictions using patient age = 55 have F1-Score = 0.7774
# Predictions using patient age = 60 have F1-Score = 0.7891
# Predictions using patient age = 65 have F1-Score = 0.7881
# Predictions using patient age = 70 have F1-Score = 0.7885
# Predictions using patient age = 75 have F1-Score = 0.7963

# %%
r.acc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Accuracy = 0.7375
# Predictions using patient age = 25 have Accuracy = 0.7531
# Predictions using patient age = 30 have Accuracy = 0.7688
# Predictions using patient age = 35 have Accuracy = 0.7906
# Predictions using patient age = 40 have Accuracy = 0.8031
# Predictions using patient age = 45 have Accuracy = 0.8156
# Predictions using patient age = 50 have Accuracy = 0.8063
# Predictions using patient age = 55 have Accuracy = 0.8031
# Predictions using patient age = 60 have Accuracy = 0.8063
# Predictions using patient age = 65 have Accuracy = 0.8000
# Predictions using patient age = 70 have Accuracy = 0.7937
# Predictions using patient age = 75 have Accuracy = 0.7937

# %%
r.bacc_per_age_older50()
# Out:
# Predictions using patient age = 20 have Balanced Accuracy = 0.7308
# Predictions using patient age = 25 have Balanced Accuracy = 0.7470
# Predictions using patient age = 30 have Balanced Accuracy = 0.7630
# Predictions using patient age = 35 have Balanced Accuracy = 0.7857
# Predictions using patient age = 40 have Balanced Accuracy = 0.7987
# Predictions using patient age = 45 have Balanced Accuracy = 0.8120
# Predictions using patient age = 50 have Balanced Accuracy = 0.8033
# Predictions using patient age = 55 have Balanced Accuracy = 0.8007
# Predictions using patient age = 60 have Balanced Accuracy = 0.8047
# Predictions using patient age = 65 have Balanced Accuracy = 0.7991
# Predictions using patient age = 70 have Balanced Accuracy = 0.7936
# Predictions using patient age = 75 have Balanced Accuracy = 0.7946

# %%
r.roc_curves_older50()

# %%
r.precision_recall_curves_older50()

# %%
r.family_plots()

# %%
r.family_plots()

# %%
r.parents_plots()

# %%
r.parents_plots()

# %%
r.first_positives()

# %%
r.first_positives()
