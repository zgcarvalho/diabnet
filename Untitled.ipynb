# %%
import optuna

# %%
study = optuna.load_study('test','sqlite:///test_hyperopt.db')

# %%
optuna.visualization.plot_contour(study, params=['soft_label_alpha', 'train_loss'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c1faa63d3365> in <module>
# ----> 1 optuna.visualization.plot_contour(study, params=['soft_label_alpha', 'train_loss'])
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/visualization/contour.py in plot_contour(study, params)
#      63
#      64     _check_plotly_availability()
# ---> 65     return _get_contour_plot(study, params)
#      66
#      67
#
# ~/anaconda3/lib/python3.7/site-packages/optuna/visualization/contour.py in _get_contour_plot(study, params)
#      85         for input_p_name in params:
#      86             if input_p_name not in all_params:
# ---> 87                 raise ValueError("Parameter {} does not exist in your study.".format(input_p_name))
#      88         sorted_params = sorted(list(set(params)))
#      89
#
# ValueError: Parameter train_loss does not exist in your study.

# %%
optuna.visualization.plot_parallel_coordinate(study, params=['soft_label_alpha', 'flood_penalty'])
# Out:
# <div>
#
#
#             <div id="e0ab75a6-0577-4fee-bc96-22ceec7358fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0ab75a6-0577-4fee-bc96-22ceec7358fa")) {
#                     Plotly.newPlot(
#                         'e0ab75a6-0577-4fee-bc96-22ceec7358fa',
# ...

# %%
study.trials
# Out:
# [FrozenTrial(number=0, value=0.40107370416323346, datetime_start=datetime.datetime(2020, 7, 16, 18, 5, 8, 868756), datetime_complete=datetime.datetime(2020, 7, 16, 18, 5, 40, 212937), params={'dp0': 0.41160735102403007, 'flood_penalty': 0.2429793362675825, 'l1_neurons': 20, 'lambda1_dim1': 2.765973559115156e-10, 'lambda1_dim2': 1.2654973612416735e-07, 'lambda2_dim1': 1.2705253964714997e-05, 'lambda2_dim2': 0.009313869319416378, 'lr': 0.00118471107382756, 'soft_label_alpha': 0.111388584065852}, distributions={'dp0': UniformDistribution(high=0.65, low=0.35), 'flood_penalty': UniformDistribution(high=0.4, low=0.0), 'l1_neurons': IntUniformDistribution(high=48, low=4, step=1), 'lambda1_dim1': LogUniformDistribution(high=5e-06, low=1e-10), 'lambda1_dim2': LogUniformDistribution(high=5e-06, low=1e-10), 'lambda2_dim1': LogUniformDistribution(high=0.001, low=1e-05), 'lambda2_dim2': LogUniformDistribution(high=0.01, low=1e-05), 'lr': UniformDistribution(high=0.007, low=0.001), 'soft_label_alp
# ...

# %%
study.user_attrs['train_loss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a3da12ffc06a> in <module>
# ----> 1 study.user_attrs['train_loss']
#
# KeyError: 'train_loss'
